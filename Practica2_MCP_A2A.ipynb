# %% [markdown]
# <a href="https://colab.research.google.com/github/armandoordonez/AI-Engineering/blob/main/Practica2_MCP_A2A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Operación Zero-Day (Neon Breach)**

# %% [markdown]
# La aplicación web simulará una terminal de un sistema de alta seguridad de una megacorporación que acaba de ser comprometida. Los estudiantes tomarán el rol de "Handlers" (Operadores) y su misión es desplegar dos inteligencias artificiales especializadas para contener la amenaza antes de que se roben los datos.
#
# **Agente 1 (El "Netrunner"):** Su misión es conectarse a los nodos infectados (usando MCP) para extraer firmas de malware y puertos vulnerables. Es ciego y no razona, solo extrae.
#
# **Agente 2 (La "Oráculo"):** Una IA de ciberdefensa. Recibe la data cruda del Netrunner (A2A), la analiza y escupe el parche de seguridad (un script o comando de terminal) para cerrar la brecha.

# %% [markdown]
# **Setup y Servidor de Herramientas**

# %% [markdown]
# Esta celda simula el **Servidor MCP (Model Context Protocol).** En la vida real, en un entorno de ciberseguridad corporativo, estas herramientas no estarían en el mismo archivo. Serían APIs externas, scripts de Bash o consultas a una base de datos de amenazas (como VirusTotal). Aquí las "mockeamos" (simulamos) localmente para que el modelo tenga algo que "tocar" sin necesidad de levantar una infraestructura compleja de red.

# %%
# ==========================================
# CELDA 1: SETUP Y ENTORNO SEC-OPS (NO MODIFICAR)
# ==========================================
# !pip install -q -U google-generativeai

import google.generativeai as genai

# Configuración del cliente Gemini
# Entra a https://aistudio.google.com/app/apikey para sacar tu llave gratis
api_key = "AIzaSyBxRGvQee0reJpY_aK2k3ZvzuMXxKhdK3k"
genai.configure(api_key=api_key)

# --- HERRAMIENTAS MCP SIMULADAS ---
def escanear_puertos() -> str:
    """Escanea la red objetivo en busca de vulnerabilidades de red y puertos abiertos."""
    return "[+] Puertos abiertos: 4444, 22. Servicios anómalos detectados."

def analizar_firmas_malware() -> str:
    """Compara los binarios del sistema contra la base de datos de amenazas."""
    return "[+] Firma de malware detectada: Ransom.NeonBat (Severidad: CRITICA)."

# %% [markdown]
# **El Netrunner (Despliegue MCP)**

# %% [markdown]
# Simulamos el Host MCP. Aquí los estudiantes aprenden que un LLM ya no es una caja cerrada que solo adivina texto. Al darle herramientas, el modelo se da cuenta de que no sabe qué puertos están abiertos, así que decide usar la herramienta escanear_puertos() para averiguarlo empíricamente. Este agente actúa como el recolector ciego: saca la data cruda del sistema.

# %%
# ==========================================
# CELDA 2: DESPLIEGUE DEL NETRUNNER (AGENTE 1 - MCP)
# ==========================================
def desplegar_netrunner():
    print(">>> INICIANDO NETRUNNER (Extracción de Datos)...")

    # Usa las herramientas MCP definidas anteriormente
    herramientas_disponibles =  # TU CÓDIGO AQUÍ

    # Instanciamos el Agente Netrunner
    modelo_netrunner = genai.GenerativeModel(
        model_name='gemini-2.5-flash',
        tools= # TU CÓDIGO AQUÍ (Pista: pasamos el array de herramientas disponibles)
    )

    # Iniciamos sesión de chat permitiendo que ejecute las funciones solo
    chat = modelo_netrunner.start_chat(enable_automatic_function_calling=True)

    prompt = # TU INSTRUCCION AQUÍ
    respuesta = chat.send_message(prompt)

    print("[*] Datos crudos obtenidos:")
    print(respuesta.text)
    return respuesta.text

# %% [markdown]
# **Oráculo (Comportamiento)**

# %% [markdown]
# Aqui simulamos la Ingeniería de Comportamiento (System Prompting) y el Motor de Razonamiento. Aquí se demuestra que un LLM puede dejar de ser un "chatbot conversacional" para convertirse en una pieza de software determinista (un trabajador de backend). Su única función es recibir una entrada (la data cruda), aplicar reglas heurísticas (evaluar la severidad) y generar una salida ejecutable.

# %%
# ==========================================
# CELDA 3: DESPERTAR A LA ORÁCULO (AGENTE 2 - IA DEFENSIVA)
# ==========================================
def despertar_oraculo(datos_del_netrunner):
    print("\n>>> DESPERTANDO ORÁCULO (Análisis y Mitigación)...")

    # ---------------------------------------------------------
    # instruccion = Define la personalidad de la Oráculo"
    # ---------------------------------------------------------
    instruccion = # TU INSTRUCCION AQUÍ

    modelo_oraculo = genai.GenerativeModel(
        model_name='gemini-2.5-flash',
        system_instruction=# TU CÓDIGO AQUÍ
    )

    respuesta = modelo_oraculo.generate_content(f"Datos del sistema comprometido:\n{datos_del_netrunner}")

    print("[*] Plan de Mitigación Generado:")
    print(respuesta.text)
    return respuesta.text

# %% [markdown]
# **Sincronización Neural (El Handoff A2A)**

# %% [markdown]
# Esto es el corazón de Agent-to-Agent (A2A) y el principio de Separación de Responsabilidades (Separation of Concerns). En lugar de pedirle a un solo agente que extraiga los datos, los analice y cree el parche (lo cual aumenta el riesgo de que el modelo alucine o se equivoque), dividimos el trabajo. El Agente 1 (tonto pero con herramientas) le hace el "Handoff" o pase de contexto al Agente 2 (inteligente pero sin herramientas).

# %%
# ==========================================
# CELDA 4: SINCRONIZACIÓN A2A (AGENT-TO-AGENT)
# ==========================================
print("--- INICIANDO OPERACIÓN ZERO-DAY ---\n")

# Paso 1: El Netrunner saca la data
datos_extraidos = # TU CÓDIGO AQUÍ

print("\n--- INICIANDO HANDOFF NEURAL (A2A) ---\n")

# Paso 2: La Oráculo procesa la data
plan_defensa = # TU CÓDIGO AQUÍ

print("\n--- SISTEMA ASEGURADO ---")
# Out:
# --- INICIANDO OPERACIÓN ZERO-DAY ---
#
# >>> INICIANDO NETRUNNER (Extracción de Datos)...
# [*] Datos crudos obtenidos:
# Aquí están los datos crudos encontrados:
#
# **Escaneo de Puertos:**
#
# ```json
# {
#   "escanear_puertos_response": {
#     "result": "[+] Puertos abiertos: 4444, 22. Servicios anómalos detectados."
#   }
# }
# ```
#
#
# **Análisis de Firmas de Malware:**
#
# ```json
# {
#   "analizar_firmas_malware_response": {
#     "result": "[+] Firma de malware detectada: Ransom.NeonBat (Severidad: CRITICA)."
#   }
# }
# ```
#
# --- INICIANDO HANDOFF NEURAL (A2A) ---
#
#
# >>> DESPERTANDO ORÁCULO (Análisis y Mitigación)...
# [*] Plan de Mitigación Generado:
# **Reporte de Severidad:**
#
# **Severidad: CRÍTICA**
#
# ...
